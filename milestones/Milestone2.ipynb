# %% [markdown]
# <a href="https://colab.research.google.com/github/natwoshoes/ObjectDetectionModel_LatitudeAI/blob/main/Milestone2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Latitude AI 1 - Milestone 2
# ### Task:  generate 3D detections from an input image using the pretrained model. Brace yourself for challenges!

# %%
# !mkdir -p /data/sets/nuscenes  # Make the directory to store the nuScenes dataset in.

# !wget https://www.nuscenes.org/data/v1.0-mini.tgz  # Download the nuScenes mini split.

# !tar -xf v1.0-mini.tgz -C /data/sets/nuscenes  # Uncompress the nuScenes mini split.

# !pip install nuscenes-devkit &> /dev/null  # Install nuScenes.
# Out:
# --2024-09-07 18:19:17--  https://www.nuscenes.org/data/v1.0-mini.tgz
# Resolving www.nuscenes.org (www.nuscenes.org)... 13.227.219.18, 13.227.219.45, 13.227.219.76, ...
# Connecting to www.nuscenes.org (www.nuscenes.org)|13.227.219.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4167696325 (3.9G) [application/x-tar]
# Saving to: ‘v1.0-mini.tgz’
#
# v1.0-mini.tgz       100%[===================>]   3.88G  35.7MB/s    in 1m 44s
#
# 2024-09-07 18:21:02 (38.2 MB/s) - ‘v1.0-mini.tgz’ saved [4167696325/4167696325]

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
# !git clone https://github.com/cyn-liu/FastBEV.git
# Out:
# fatal: destination path 'FastBEV' already exists and is not an empty directory.

# %%
# !conda create -n FastBEV python=3.8 -y
# !conda activate FastBEV
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 23.11.0
#     latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/FastBEV
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h4bc722e_7         247 KB  conda-forge
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     ld_impl_linux-64-2.40      |       hf3520f5_7         691 KB  conda-forge
#     libgcc-14.1.0              |       h77fa898_1         827 KB  conda-forge
#     libgcc-ng-14.1.0           |       h69a702a_1          51 KB  conda-forge
# ...

# %%
# !conda install pytorch==1.10.0 torchvision==0.11.1 torchaudio==0.10.1 cudatoolkit=10.2 -c pytorch
# Out:
# Channels:
#  - pytorch
#  - conda-forge
# Platform: linux-64
# done
# | warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# failed
#
# LibMambaUnsatisfiableError: Encountered problems while solving:
#   - package torchvision-0.11.1-py36_cpu requires python >=3.6,<3.7.0a0, but none of the providers can be installed
#   - package torchaudio-0.10.1-py36_cpu requires python >=3.6,<3.7.0a0, but none of the providers can be installed
#
# Could not solve for environment specs
# The following packages are incompatible
# ├─ cudatoolkit 10.2**  is requested and can be installed;
# ├─ pin-2 is installable and it requires
# │  └─ python 3.10** , which can be installed;
# ├─ pin-3 is installable and it requires
# │  └─ python_abi 3.10* *cp310*, which can be installed;
# ├─ python 3.10**  is installable with the potential options
# ...

# %%
# !pip install -U openmim
# !mim install mmengine==0.7.0
# !mim install mmcv==2.0.0
# !mim install mmdet==3.0.0rc6
# !mim install mmdet3d==1.1.0rc3
# !mim install mmsegmentation==1.0.0rc6

# !python -r requirements.txt
# Out:
# ...
# Traceback (most recent call last):
#   File "/usr/local/bin/mim", line 8, in <module>
#     sys.exit(cli())
#   File "/usr/local/lib/python3.10/site-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.10/site-packages/click/core.py", line 1078, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.10/site-packages/click/core.py", line 1688, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/usr/local/lib/python3.10/site-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.10/site-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "/usr/local/lib/python3.10/site-packages/mim/commands/install.py", line 72, in cli
#     exit_code = install(list(args), index_url=index_url, is_yes=is_yes)
# ...

# %%
# !pip install mmdet3d
# Out:
# ...
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached numba-0.60.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.7 kB)
# ...
#   Using cached nuscenes_devkit-1.1.11-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# ...
#   Using cached pyquaternion-0.9.9-py3-none-any.whl.metadata (1.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 2.5 MB/s eta 0:00:00
# ...
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# ...
#   Using cached shapely-2.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# ...
#   Using cached fire-0.6.0-py2.py3-none-any.whl
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 4.6 MB/s eta 0:00:00
# ...
#   Using cached llvmlite-0.43.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# ...

# %% [markdown]
# ## Selecting a random image for Fast BEV Testing
